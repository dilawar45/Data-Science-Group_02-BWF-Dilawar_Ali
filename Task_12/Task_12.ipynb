# %% [markdown]
# **Task 12: Introduction to Pandas (Series, DataFrame basics)**

# %%
import pandas as pd
import numpy as np

# %%
# 1. Create a Pandas Series from a Python list, numpy array, and a dictionary.
python_list = [10, 20, 30, 40, 50]
numpy_array = np.array([1, 2, 3, 4, 5])
dictionary = {'a': 100, 'b': 200, 'c': 300}

series_from_list = pd.Series(python_list)
series_from_array = pd.Series(numpy_array)
series_from_dict = pd.Series(dictionary)

# %%
# 2. Assign a custom index to the Series.
custom_index_series = pd.Series(python_list, index=['A', 'B', 'C', 'D', 'E'])
custom_index_series
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
# 3. Perform basic arithmetic operations on Series.
series1 = pd.Series([1, 2, 3, 4, 5])
series2 = pd.Series([10, 20, 30, 40, 50])

addition = series1 + series2
subtraction = series1 - series2
multiplication = series1 * series2
division = series1 / series2

print("Addition:",'\n',addition)
print("Subtraction:",'\n',subtraction)
print("Multiplication:",'\n', multiplication)
print("Division:",'\n', division)
# Out:
# Addition:
#  0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64
# Subtraction:
#  0    -9
# 1   -18
# 2   -27
# 3   -36
# 4   -45
# dtype: int64
# Multiplication:
#  0     10
# 1     40
# 2     90
# 3    160
# 4    250
# dtype: int64
# Division:
#  0    0.1
# 1    0.1
# 2    0.1
# 3    0.1
# 4    0.1
# dtype: float64

# %%
# 4. Access elements using index labels and positions.
element_by_label = custom_index_series['B']
element_by_position = custom_index_series.iloc[1]
print("Element by Label:", element_by_label)
print("Element by Position:", element_by_position)
# Out:
# Element by Label: 20
# Element by Position: 20

# %%
# 5. Filter the Series to include only values greater than a specific threshold.
filtered_series = series1[series1 > 2]
print("Filtered Series:", filtered_series)
# Out:
# Filtered Series: 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# 6. Create a DataFrame from a dictionary of lists.
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank'],
    'Age': [25, 30, 35, 28, 22, 45],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia']
}
df_from_dict = pd.DataFrame(data)
df_from_dict
# Out:
#       Name  Age          City
# 0    Alice   25      New York
# 1      Bob   30   Los Angeles
# 2  Charlie   35       Chicago
# 3    David   28       Houston
# 4      Eve   22       Phoenix
# 5    Frank   45  Philadelphia

# %%
# 7. Create a DataFrame from a numpy array, specifying column and index names.
array_data = np.random.rand(4, 3)
df_from_array = pd.DataFrame(array_data, columns=['Column1', 'Column2', 'Column3'], index=['Row1', 'Row2', 'Row3', 'Row4'])
df_from_array
# Out:
#        Column1   Column2   Column3
# Row1  0.805342  0.862406  0.312102
# Row2  0.158727  0.186378  0.780486
# Row3  0.029546  0.043601  0.701072
# Row4  0.859326  0.082606  0.436552

# %% [markdown]
# **DataFrame from CSV**

# %%
df = pd.read_csv("/content/drive/MyDrive/covid_19_clean_complete.csv")
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 0              0       0          0       0  Eastern Mediterranean
# 1              0       0          0       0                 Europe
# 2              0       0          0       0                 Africa
# 3              0       0          0       0                 Europe
# 4              0       0          0       0                 Africa
# ...          ...     ...        ...     ...                    ...
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa
#
# [49068 rows x 10 columns]

# %% [markdown]
# **Display the first and last five rows of the DataFrame.**

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.tail()
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa

# %% [markdown]
# summary of the DataFrame including the mean, median, and standard deviation of numeric columns.

# %%
df.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
Countries = df['Country/Region']
print("\nSeries extracted from 'Country/Region' column:")
print(Countries)
# Out:
# Series extracted from 'Country/Region' column:
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3                      Andorra
# 4                       Angola
#                  ...
# 49063    Sao Tome and Principe
# 49064                    Yemen
# 49065                  Comoros
# 49066               Tajikistan
# 49067                  Lesotho
# Name: Country/Region, Length: 49068, dtype: object

# %% [markdown]
# **Filter rows based on column values**

# %%
filtered_df = df[df['Country/Region'] == 'Albania']
filtered_df
# Out:
#       Province/State Country/Region      Lat     Long        Date  Confirmed  \
# 1                NaN        Albania  41.1533  20.1683  2020-01-22          0
# 262              NaN        Albania  41.1533  20.1683  2020-01-23          0
# 523              NaN        Albania  41.1533  20.1683  2020-01-24          0
# 784              NaN        Albania  41.1533  20.1683  2020-01-25          0
# 1045             NaN        Albania  41.1533  20.1683  2020-01-26          0
# ...              ...            ...      ...      ...         ...        ...
# 47764            NaN        Albania  41.1533  20.1683  2020-07-23       4466
# 48025            NaN        Albania  41.1533  20.1683  2020-07-24       4570
# 48286            NaN        Albania  41.1533  20.1683  2020-07-25       4637
# 48547            NaN        Albania  41.1533  20.1683  2020-07-26       4763
# 48808            NaN        Albania  41.1533  20.1683  2020-07-27       4880
#
#        Deaths  Recovered  Active WHO Region
# 1           0          0       0     Europe
# 262         0          0       0     Europe
# 523         0          0       0     Europe
# 784         0          0       0     Europe
# 1045        0          0       0     Europe
# ...       ...        ...     ...        ...
# 47764     123       2523    1820     Europe
# 48025     128       2608    1834     Europe
# 48286     134       2637    1866     Europe
# 48547     138       2682    1943     Europe
# 48808     144       2745    1991     Europe
#
# [188 rows x 10 columns]

# %%
average_confirmed = df['Confirmed'].mean()
filtered_df = df[df['Confirmed'] > average_confirmed]
filtered_df
# Out:
#       Province/State        Country/Region        Lat        Long        Date  \
# 3715           Hubei                 China  30.975600  112.270700  2020-02-05
# 3976           Hubei                 China  30.975600  112.270700  2020-02-06
# 4237           Hubei                 China  30.975600  112.270700  2020-02-07
# 4498           Hubei                 China  30.975600  112.270700  2020-02-08
# 4759           Hubei                 China  30.975600  112.270700  2020-02-09
# ...              ...                   ...        ...         ...         ...
# 49020            NaN               Ukraine  48.379400   31.165600  2020-07-27
# 49021            NaN  United Arab Emirates  23.424076   53.847818  2020-07-27
# 49028            NaN        United Kingdom  55.378100   -3.436000  2020-07-27
# 49030            NaN                    US  40.000000 -100.000000  2020-07-27
# 49031            NaN            Uzbekistan  41.377491   64.585262  2020-07-27
#
#        Confirmed  Deaths  Recovered   Active             WHO Region
# 3715       19665     549        633    18483        Western Pacific
# 3976       22112     618        817    20677        Western Pacific
# 4237       24953     699       1115    23139        Western Pacific
# 4498       27100     780       1439    24881        Western Pacific
# 4759       29631     871       1795    26965        Western Pacific
# ...          ...     ...        ...      ...                    ...
# 49020      67096    1636      37202    28258                 Europe
# 49021      59177     345      52510     6322  Eastern Mediterranean
# 49028     300111   45759          0   254352                 Europe
# 49030    4290259  148011    1325804  2816444               Americas
# 49031      21209     121      11674     9414                 Europe
#
# [4878 rows x 10 columns]

# %% [markdown]
# **Select rows based on multiple conditions.**

# %%
high_confirmed_cases = df[(df['Country/Region'] == 'Albania') & (df['Confirmed'] > 8)]
high_confirmed_cases
# Out:
#       Province/State Country/Region      Lat     Long        Date  Confirmed  \
# 12529            NaN        Albania  41.1533  20.1683  2020-03-10         10
# 12790            NaN        Albania  41.1533  20.1683  2020-03-11         12
# 13051            NaN        Albania  41.1533  20.1683  2020-03-12         23
# 13312            NaN        Albania  41.1533  20.1683  2020-03-13         33
# 13573            NaN        Albania  41.1533  20.1683  2020-03-14         38
# ...              ...            ...      ...      ...         ...        ...
# 47764            NaN        Albania  41.1533  20.1683  2020-07-23       4466
# 48025            NaN        Albania  41.1533  20.1683  2020-07-24       4570
# 48286            NaN        Albania  41.1533  20.1683  2020-07-25       4637
# 48547            NaN        Albania  41.1533  20.1683  2020-07-26       4763
# 48808            NaN        Albania  41.1533  20.1683  2020-07-27       4880
#
#        Deaths  Recovered  Active WHO Region
# 12529       0          0      10     Europe
# 12790       1          0      11     Europe
# 13051       1          0      22     Europe
# 13312       1          0      32     Europe
# 13573       1          0      37     Europe
# ...       ...        ...     ...        ...
# 47764     123       2523    1820     Europe
# 48025     128       2608    1834     Europe
# 48286     134       2637    1866     Europe
# 48547     138       2682    1943     Europe
# 48808     144       2745    1991     Europe
#
# [140 rows x 10 columns]

# %%
low_confirmed_with_deaths = df[(df['Confirmed'] < 10) & (df['Deaths'] == 1)]
low_confirmed_with_deaths
# Out:
#                Province/State  Country/Region      Lat      Long        Date  \
# 318                     Hebei           China  39.5490  116.1306  2020-01-23
# 579                     Hebei           China  39.5490  116.1306  2020-01-24
# 580              Heilongjiang           China  47.8620  127.7615  2020-01-24
# 840                     Hebei           China  39.5490  116.1306  2020-01-25
# 841              Heilongjiang           China  47.8620  127.7615  2020-01-25
# ...                       ...             ...      ...       ...         ...
# 48009  British Virgin Islands  United Kingdom  18.4207  -64.6400  2020-07-23
# 48270  British Virgin Islands  United Kingdom  18.4207  -64.6400  2020-07-24
# 48531  British Virgin Islands  United Kingdom  18.4207  -64.6400  2020-07-25
# 48792  British Virgin Islands  United Kingdom  18.4207  -64.6400  2020-07-26
# 49053  British Virgin Islands  United Kingdom  18.4207  -64.6400  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active       WHO Region
# 318            1       1          0       0  Western Pacific
# 579            2       1          0       1  Western Pacific
# 580            4       1          0       3  Western Pacific
# 840            8       1          0       7  Western Pacific
# 841            9       1          0       8  Western Pacific
# ...          ...     ...        ...     ...              ...
# 48009          8       1          7       0           Europe
# 48270          8       1          7       0           Europe
# 48531          8       1          7       0           Europe
# 48792          8       1          7       0           Europe
# 49053          8       1          7       0           Europe
#
# [431 rows x 10 columns]

# %% [markdown]
# **new column to the DataFrame**

# %%
df['TotalCases'] = df['Confirmed'] + df['Deaths'] + df['Recovered']
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region  TotalCases
# 0       0          0       0  Eastern Mediterranean           0
# 1       0          0       0                 Europe           0
# 2       0          0       0                 Africa           0
# 3       0          0       0                 Europe           0
# 4       0          0       0                 Africa           0

# %% [markdown]
# **Rename columns in the DataFrame**

# %%
df = df.rename(columns={'Country/Region': 'Country', 'Province/State': 'State'})
df.head()
# Out:
#   State      Country       Lat       Long        Date  Confirmed  Deaths  \
# 0   NaN  Afghanistan  33.93911  67.709953  2020-01-22          0       0
# 1   NaN      Albania  41.15330  20.168300  2020-01-22          0       0
# 2   NaN      Algeria  28.03390   1.659600  2020-01-22          0       0
# 3   NaN      Andorra  42.50630   1.521800  2020-01-22          0       0
# 4   NaN       Angola -11.20270  17.873900  2020-01-22          0       0
#
#    Recovered  Active             WHO Region  TotalCases
# 0          0       0  Eastern Mediterranean           0
# 1          0       0                 Europe           0
# 2          0       0                 Africa           0
# 3          0       0                 Europe           0
# 4          0       0                 Africa           0
